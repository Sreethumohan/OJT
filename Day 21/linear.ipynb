# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
height=np.array([150,160,164,165,173]).reshape(-1,1)
weight=np.array([50,65,63,68,72])

# %%
model=LinearRegression()
model.fit(height,weight)
# Out:
# LinearRegression()

# %%
predicted_weight=model.predict(height)
print(f"Intercept : {model.intercept_}")
# Out:
# Intercept : -89.3285917496444

# %%
print(f"coefficient: {model.coef_[0]}")
# Out:
# coefficient: 0.9416785206258891

# %%
plt.scatter(height,weight,color='orange')
plt.plot(height,predicted_weight,color='lime')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Linear Regression')
plt.show()
