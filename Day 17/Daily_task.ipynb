# %%
#1. Convert 1D array with 8 elements to 3D array with 2x2 elements
import numpy as np
array_1D = np.array([1, 2, 3, 4, 5, 6, 7, 8])
array_3D = array_1D.reshape(2, 2, 2)
array_3D
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
#2. Convert the array into a 1D array
array_1D_again = array_3D.flatten()
array_1D_again
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
#3.Use the scatter() method to draw a scatter plot diagram
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [8, 7, 6, 5, 4, 3, 2, 1]
plt.scatter(x, y)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Sample Scatter Plot')
plt.show()

# %%
#4. A scatter plot with 1000 dots
np.random.seed(0)
x_1000 = np.random.rand(1000)
y_1000 = np.random.rand(1000)
plt.scatter(x_1000, y_1000)
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Scatter Plot with 1000 Dots')
plt.show()

# %%
#5. Fit a linear regression model using scikit-learn for the data points x = [1, 2, 3, 4, 5] and y = [2, 3, 5, 7, 11]. Predict the value of y when x = 6.
from sklearn.linear_model import LinearRegression
x = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)
y = np.array([2, 3, 5, 7, 11])
model = LinearRegression()
model.fit(x, y)
x_new = np.array([[6]])
y_pred = model.predict(x_new)
y_pred
# Out:
# array([12.2])
